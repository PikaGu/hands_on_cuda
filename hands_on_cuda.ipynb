# %%
# !git clone --recurse-submodules https://github.com/PikaGu/hands_on_cuda.git
# Out:
# Cloning into 'hands_on_cuda'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 31 (delta 2), reused 27 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 6.31 KiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Submodule 'external/pybind11' (https://github.com/pybind/pybind11.git) registered for path 'external/pybind11'
# Cloning into '/content/hands_on_cuda/external/pybind11'...
# remote: Enumerating objects: 30172, done.
# remote: Counting objects: 100% (766/766), done.
# remote: Compressing objects: 100% (391/391), done.
# remote: Total 30172 (delta 625), reused 375 (delta 375), pack-reused 29406 (from 4)
# Receiving objects: 100% (30172/30172), 11.95 MiB | 10.08 MiB/s, done.
# Resolving deltas: 100% (21307/21307), done.
# Submodule path 'external/pybind11': checked out '945e251a6ce7273058b36214d94415e9c9530b8e'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/Othercomputers/Mac/hands_on_cuda
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/Othercomputers/Mac/hands_on_cuda
# build/    CMakeLists.txt  external/            main.py  test.py
# build.sh  cuda_demo.so    hands_on_cuda.ipynb  src/

# %%
# !sudo apt-get update
# !sudo apt-get install -y cmake g++
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [61.9 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,200 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,645 kB]
# ...

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Tue Jan 21 07:38:44 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# ...

# %%
# !sh build.sh
# Out:
# -- pybind11 v2.14.0 dev1
# -- Found PythonInterp: /usr/bin/python3 (found suitable version "3.11.11", minimum required is "3.8")
# -- Found PythonLibs: /usr/lib/x86_64-linux-gnu/libpython3.10.so
# -- Configuring done (6.0s)
# -- Generating done (5.4s)
# -- Build files have been written to: /content/drive/Othercomputers/Mac/hands_on_cuda/build
# [-33%] Building CUDA object CMakeFiles/cuda_demo.dir/src/kernel/add.cu.o
# [  0%] Building CXX object CMakeFiles/cuda_demo.dir/src/pybind11_module.cpp.o
# [ 33%] Linking CXX shared module cuda_demo.so
# [ 33%] Built target cuda_demo
# Build complete. Output located in: build

# %%
# !python3 main.py
# Out:
# Result: [0.40945527 0.47005302 0.9445671  0.91549796 0.56112504 0.80649084
#  1.079968   0.7512639  0.8438336  0.7684439  0.97411734 0.30410784
#  1.0799117  0.22336572 1.3592957  0.8837892  1.1012918  1.1352149
#  0.61778414 0.9264126  0.54321486 1.2616106  1.6828753  0.8117405
#  0.9839113  0.95364785 0.71042746 1.0106592  1.6568823  1.1154299
#  0.42619509 1.5863776  0.7417786  0.35185722 0.8327965  1.8840685
#  0.30441192 1.5637766  0.7657746  0.75158876 0.9451852  1.3586855
#  0.05091123 0.9160018  0.47700694 1.0796268  0.66105366 1.4057226
#  1.1154275  1.2010759 ]
# Expected: [0.40945527 0.47005302 0.9445671  0.91549796 0.56112504 0.80649084
#  1.079968   0.7512639  0.8438336  0.7684439  0.97411734 0.30410784
#  1.0799117  0.22336572 1.3592957  0.8837892  1.1012918  1.1352149
#  0.61778414 0.9264126  0.54321486 1.2616106  1.6828753  0.8117405
#  0.9839113  0.95364785 0.71042746 1.0106592  1.6568823  1.1154299
#  0.42619509 1.5863776  0.7417786  0.35185722 0.8327965  1.8840685
# ...

# %%
# !python3 test.py
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.251s
#
# OK

# %%
# !find / -name "nsys"
# /opt/nvidia/nsight-compute/2023.2.2/host/target-linux-x64/nsys
# !/opt/nvidia/nsight-compute/2023.2.2/host/target-linux-x64/nsys profile --stat=true python3 test.py
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.546s
#
# OK
# Generating '/tmp/nsys-report-dbd0.qdstrm'
# [1/8] [========================100%] report1.nsys-rep
# [2/8] [========================100%] report1.sqlite
# [3/8] Executing 'nvtx_sum' stats report
# SKIPPED: /content/drive/Othercomputers/Mac/hands_on_cuda/report1.sqlite does not contain NV Tools Extension (NVTX) data.
# [4/8] Executing 'osrt_sum' stats report
#
#  Time (%)  Total Time (ns)  Num Calls    Avg (ns)     Med (ns)    Min (ns)   Max (ns)    StdDev (ns)           Name
#  --------  ---------------  ---------  ------------  -----------  --------  -----------  ------------  ---------------------
#      54.6      200,614,958         13  15,431,919.8  2,734,788.0     3,623  100,185,967  28,722,759.7  poll
#      41.0      150,812,375        541     278,765.9     12,353.0       416  100,328,062   4,350,243.9  ioctl
# ...

# %%
# !ncu --target-processes all python3 test.py
# Out:
# ==PROF== Connected to process 6985 (/usr/bin/python3.11)
# ==PROF== Profiling "add" - 0: 0%....50%....100% - 8 passes
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.909s
#
# OK
# ==PROF== Disconnected from process 6985
# [6985] python3.11@127.0.0.1
#   add(const float *, const float *, float *, int) (4, 1, 1)x(256, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ------------- ------------
#     Metric Name               Metric Unit Metric Value
#     ----------------------- ------------- ------------
#     DRAM Frequency          cycle/nsecond         4.73
#     SM Frequency            cycle/usecond       557.97
#     Elapsed Cycles                  cycle        2,143
#     Memory Throughput                   %         0.83
#     DRAM Throughput                     %         0.83
#     Duration                      usecond         3.84
# ...
